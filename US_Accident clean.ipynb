# %%
import pandas as pd
import numpy as np

# %%
# Mở file csv
df = pd.read_csv(r'C:\Users\Admin\OneDrive\Documents\data\US_Accidents_Dec21_updated.csv')

# %%
pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#      ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0   A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1   A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2   A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3   A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4   A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# 5   A-6         2  2016-02-08 08:16:57  2016-02-08 14:16:57  39.063240
# 6   A-7         2  2016-02-08 08:15:41  2016-02-08 14:15:41  39.775650
# 7   A-8         2  2016-02-08 11:51:46  2016-02-08 17:51:46  41.375310
# 8   A-9         2  2016-02-08 14:19:57  2016-02-08 20:19:57  40.702247
# 9  A-10         2  2016-02-08 15:16:43  2016-02-08 21:16:43  40.109310
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'])
df['End_Time'] = pd.to_datetime(df['End_Time'])
# df['Start_Time'] = df['Start_Time'].astype('datetime')
# df['End_Time'] = df['End_Time'].astype('datetime')

# %%
df_city = df.groupby('City', as_index = False).agg(Accident = ('ID', 'count'))
df_city = df_city.sort_values(['Accident'], ascending = False)
df_city.reset_index(inplace = True, drop = True)
df_city.head(20)
# Out:
#             City  Accident
# 0          Miami    106966
# 1    Los Angeles     68956
# 2        Orlando     54691
# 3         Dallas     41979
# 4        Houston     39448
# 5      Charlotte     33152
# 6     Sacramento     32559
# 7      San Diego     26627
# 8        Raleigh     22840
# 9    Minneapolis     22768
# 10      Portland     20944
# 11     Nashville     20267
# 12        Austin     18301
# 13   Baton Rouge     18182
# 14       Phoenix     17143
# 15    Saint Paul     16869
# 16   New Orleans     16251
# 17       Atlanta     15622
# 18  Jacksonville     14967
# 19      Richmond     14349

# %%
df_county = df.groupby('County', as_index = False).agg(Accident = ('ID', 'count'))
df_county = df_county.sort_values(['Accident'], ascending = False)
df_county.reset_index(inplace = True, drop = True)
df_county.head(20)
# Out:
#             County  Accident
# 0      Los Angeles    234122
# 1       Miami-Dade    143939
# 2           Orange    114917
# 3   San Bernardino     55018
# 4           Dallas     50050
# 5        San Diego     48366
# 6       Sacramento     46708
# 7           Harris     42559
# 8        Riverside     42176
# 9       Montgomery     41476
# 10         Alameda     38997
# 11     Mecklenburg     35191
# 12        Maricopa     33539
# 13            Wake     31662
# 14     Santa Clara     27415
# 15        Hennepin     26560
# 16        Davidson     26259
# 17            Lake     23584
# 18          Marion     22437
# 19            Cook     21335

# %%
df_state = df.groupby('State', as_index = False).agg(Accident = ('ID', 'count'))
df_state = df_state.sort_values(['Accident'], ascending = False)
df_state.reset_index(inplace = True, drop = True)
df_state.head(20)
# Out:
#    State  Accident
# 0     CA    795868
# 1     FL    401388
# 2     TX    149037
# 3     OR    126341
# 4     VA    113535
# 5     NY    108049
# 6     PA     99975
# 7     MN     97185
# 8     NC     91362
# 9     SC     89216
# 10    MD     65085
# 11    AZ     56504
# 12    NJ     52902
# 13    TN     52613
# 14    UT     49193
# 15    LA     47232
# 16    IL     47105
# 17    MI     43843
# 18    GA     40086
# 19    WA     32554

# %%
df_twilight = df.groupby('Civil_Twilight', as_index = False).agg(Accident = ('ID', 'count'))
df_twilight = df_twilight.sort_values(['Accident'], ascending = False)
df_twilight.reset_index(inplace = True, drop = True)
df_twilight.head(20)
# Out:
#   Civil_Twilight  Accident
# 0            Day   1929103
# 1          Night    913372

# %%
# df['Start_Hour'] = df['Start_Time'].dt.hour
# df['End_Hour'] = df['End_Time'].dt.hour
df['Start_Hour'] = pd.to_datetime(df['Start_Time']).dt.hour
df['End_Hour'] = pd.to_datetime(df['End_Time']).dt.hour
df['Start_Year'] = pd.to_datetime(df['Start_Time']).dt.year

# %%
df['Duration'] = df['End_Time'] - df['Start_Time']

# %%
df_duration = df.groupby('Duration', as_index = False).agg(Accident = ('ID', 'count'))
df_duration = df_duration.sort_values(['Accident'], ascending = False)
df_duration.reset_index(inplace = True, drop = True)
df_duration.head(20)
# Out:
#           Duration  Accident
# 0  0 days 06:00:00    353058
# 1  0 days 04:00:00     55394
# 2  0 days 00:15:00     37038
# 3  0 days 00:30:00     35345
# 4  0 days 01:00:00     28845
# 5  0 days 01:15:00     25794
# 6  0 days 01:45:00     24615
# 7  0 days 00:45:00     18568
# 8  0 days 02:00:00     16625
# 9  0 days 00:20:00     12938
# 10 0 days 00:34:58     11343
# 11 0 days 01:15:01     11186
# 12 0 days 00:59:00      8269
# 13 0 days 00:49:58      6229
# 14 0 days 00:20:30      5763
# 15 0 days 02:45:00      5719
# 16 0 days 01:18:01      5346
# 17 0 days 00:21:00      4803
# 18 0 days 00:29:30      4353
# 19 0 days 01:04:58      4278

# %%
df_severity = df.groupby('Severity', as_index = False).agg(Accident = ('ID', 'count'))
df_severity = df_severity.sort_values(['Accident'], ascending = False)
df_severity.reset_index(inplace = True, drop = True)
df_severity.head(20)
# Out:
#    Severity  Accident
# 0         2   2532991
# 1         3    155105
# 2         4    131193
# 3         1     26053

# %%
df_severity = df.groupby(['Severity','Duration'], as_index = False).agg(Accident = ('ID', 'count'))
df_severity = df_severity.sort_values(['Accident'], ascending = False)
df_severity.reset_index(inplace = True, drop = True)
df_severity.head(20)
# Out:
#     Severity        Duration  Accident
# 0          2 0 days 06:00:00    240824
# 1          3 0 days 06:00:00     65892
# 2          2 0 days 04:00:00     53635
# 3          4 0 days 06:00:00     46337
# 4          2 0 days 01:15:00     24849
# 5          2 0 days 01:45:00     24070
# 6          2 0 days 01:00:00     22082
# 7          2 0 days 00:30:00     20261
# 8          2 0 days 00:15:00     16769
# 9          2 0 days 02:00:00     15101
# 10         2 0 days 00:20:00     12930
# 11         2 0 days 01:15:01     10896
# 12         3 0 days 00:30:00     10215
# 13         3 0 days 00:15:00     10137
# 14         2 0 days 00:45:00      8932
# 15         2 0 days 00:59:00      8263
# 16         1 0 days 00:15:00      7934
# 17         2 0 days 00:20:30      5760
# 18         2 0 days 02:45:00      5301
# 19         2 0 days 01:18:01      5250

# %%
df_weather = df.groupby('Weather_Condition', as_index = False).agg(Accident = ('ID', 'count'))
df_weather = df_weather.sort_values(['Accident'], ascending = False)
df_weather.reset_index(inplace = True, drop = True)
df_weather.head(20)
# Out:
#           Weather_Condition  Accident
# 0                      Fair   1107194
# 1             Mostly Cloudy    363959
# 2                    Cloudy    348767
# 3             Partly Cloudy    249939
# 4                     Clear    173823
# 5                Light Rain    128403
# 6                  Overcast     84882
# 7          Scattered Clouds     45132
# 8                Light Snow     43752
# 9                       Fog     41226
# 10                     Haze     36354
# 11                     Rain     31044
# 12             Fair / Windy     15195
# 13               Heavy Rain     11824
# 14                    Smoke      7200
# 15            Light Drizzle      7041
# 16  Thunder in the Vicinity      6944
# 17           Cloudy / Windy      6839
# 18                  T-Storm      6546
# 19    Mostly Cloudy / Windy      6297

# %%
df_year = df.groupby('Start_Year', as_index = False).agg(Accident = ('ID', 'count'))
df_year = df_year.sort_values(['Accident'], ascending = False)
df_year.reset_index(inplace = True, drop = True)
df_year.head(20)
# Out:
#    Start_Year  Accident
# 0        2021   1511745
# 1        2020    625864
# 2        2019    258615
# 3        2017    163918
# 4        2018    163176
# 5        2016    122024

# %%
df_start = df.groupby('Start_Hour', as_index = False).agg(Accident = ('ID', 'count'))
df_start = df_start.sort_values(['Start_Hour'], ascending = True)
df_start.reset_index(inplace = True, drop = True)
df_start.head(24)
# Out:
#     Start_Hour  Accident
# 0            0     68800
# 1            1     59370
# 2            2     55443
# 3            3     48656
# 4            4     51805
# 5            5     80303
# 6            6    111160
# 7            7    135191
# 8            8    130879
# 9            9    108779
# 10          10    103926
# 11          11    113271
# 12          12    143715
# 13          13    166473
# 14          14    191480
# 15          15    214264
# 16          16    218385
# 17          17    220358
# 18          18    168982
# 19          19    116911
# 20          20     94682
# 21          21     87078
# 22          22     81188
# 23          23     74243

# %%
df_start = df.groupby(['Start_Hour','Start_Year'], as_index = False).agg(Accident = ('ID', 'count'))
df_start = df_start.sort_values(['Start_Year'], ascending = True)
df_start.reset_index(inplace = True, drop = True)
df_start.head(20)
# Out:
#     Start_Hour  Start_Year  Accident
# 0            0        2016      1453
# 1            6        2016      6512
# 2            8        2016      9764
# 3            9        2016      7262
# 4            5        2016      3612
# 5           22        2016      1536
# 6           10        2016      5735
# 7           11        2016      5352
# 8            4        2016      1862
# 9           23        2016      1514
# 10          12        2016      6570
# 11          13        2016      5985
# 12           3        2016      1581
# 13          14        2016      7061
# 14          15        2016      8853
# 15           7        2016      9213
# 16          20        2016      2751
# 17           2        2016      1063
# 18          16        2016      9430
# 19          21        2016      1397

# %%
us_states = {'AK': 'Alaska',
 'AL': 'Alabama',
 'AR': 'Arkansas',
 'AS': 'American Samoa',
 'AZ': 'Arizona',
 'CA': 'California',
 'CO': 'Colorado',
 'CT': 'Connecticut',
 'DC': 'District of Columbia',
 'DE': 'Delaware',
 'FL': 'Florida',
 'GA': 'Georgia',
 'GU': 'Guam',
 'HI': 'Hawaii',
 'IA': 'Iowa',
 'ID': 'Idaho',
 'IL': 'Illinois',
 'IN': 'Indiana',
 'KS': 'Kansas',
 'KY': 'Kentucky',
 'LA': 'Louisiana',
 'MA': 'Massachusetts',
 'MD': 'Maryland',
 'ME': 'Maine',
 'MI': 'Michigan',
 'MN': 'Minnesota',
 'MO': 'Missouri',
 'MP': 'Northern Mariana Islands',
 'MS': 'Mississippi',
 'MT': 'Montana',
 'NC': 'North Carolina',
 'ND': 'North Dakota',
 'NE': 'Nebraska',
 'NH': 'New Hampshire',
 'NJ': 'New Jersey',
 'NM': 'New Mexico',
 'NV': 'Nevada',
 'NY': 'New York',
 'OH': 'Ohio',
 'OK': 'Oklahoma',
 'OR': 'Oregon',
 'PA': 'Pennsylvania',
 'PR': 'Puerto Rico',
 'RI': 'Rhode Island',
 'SC': 'South Carolina',
 'SD': 'South Dakota',
 'TN': 'Tennessee',
 'TX': 'Texas',
 'UT': 'Utah',
 'VA': 'Virginia',
 'VI': 'Virgin Islands',
 'VT': 'Vermont',
 'WA': 'Washington',
 'WI': 'Wisconsin',
 'WV': 'West Virginia',
 'WY': 'Wyoming'}

# %%
df['State'] = df['State'].map(us_states).fillna(df['State'])

# %%
print(len(df['State'].unique()))
# Out:
# 49

# %%
df
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 0              A-1         3 2016-02-08 00:37:08 2016-02-08 06:37:08
# 1              A-2         2 2016-02-08 05:56:20 2016-02-08 11:56:20
# 2              A-3         2 2016-02-08 06:15:39 2016-02-08 12:15:39
# 3              A-4         2 2016-02-08 06:51:45 2016-02-08 12:51:45
# 4              A-5         3 2016-02-08 07:53:43 2016-02-08 13:53:43
# ...            ...       ...                 ...                 ...
# 2845337  A-2845338         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 2845338  A-2845339         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 2845339  A-2845340         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 2845340  A-2845341         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 2845341  A-2845342         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0        40.108910  -83.092860  40.112060  -83.031870         3.230
# ...

# %%
df['Temperature(C)'] = round((df['Temperature(F)']-32)*5/9,1)
df['Wind_Chill(C)'] = round((df['Wind_Chill(F)']-32)*5/9,1)
df['Visibility(km)'] = round(df['Visibility(mi)']*1.609344,1)
df['Wind_Speed(km/h)'] = round(df['Wind_Speed(mph)']*1.609344,1)
df['Precipitation(mm)'] = df['Precipitation(in)']*25.4
df['Distance(km)'] = round(df['Distance(mi)']*1.609344,1)

# %%
new_df = df[['ID','Severity','Start_Time','End_Time','Start_Year','Duration','Start_Hour','End_Hour','Distance(km)','Side','City','County','State','Temperature(C)','Wind_Chill(C)','Humidity(%)','Pressure(in)','Visibility(km)','Wind_Direction','Wind_Speed(km/h)','Precipitation(mm)',
'Weather_Condition','Amenity','Bump','Crossing','Give_Way','Junction','No_Exit','Railway','Roundabout','Station','Stop','Traffic_Calming','Traffic_Signal','Turning_Loop','Civil_Twilight']]

# %%
new_df
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 0              A-1         3 2016-02-08 00:37:08 2016-02-08 06:37:08
# 1              A-2         2 2016-02-08 05:56:20 2016-02-08 11:56:20
# 2              A-3         2 2016-02-08 06:15:39 2016-02-08 12:15:39
# 3              A-4         2 2016-02-08 06:51:45 2016-02-08 12:51:45
# 4              A-5         3 2016-02-08 07:53:43 2016-02-08 13:53:43
# ...            ...       ...                 ...                 ...
# 2845337  A-2845338         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 2845338  A-2845339         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 2845339  A-2845340         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 2845340  A-2845341         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 2845341  A-2845342         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Year        Duration  Start_Hour  End_Hour  Distance(km) Side  \
# ...

# %%
import matplotlib.pylab as plt

# %%
import seaborn as sns

# %%
new_df.corr
# Out:
# <bound method DataFrame.corr of                 ID  Severity          Start_Time            End_Time  \
# 0              A-1         3 2016-02-08 00:37:08 2016-02-08 06:37:08
# 1              A-2         2 2016-02-08 05:56:20 2016-02-08 11:56:20
# 2              A-3         2 2016-02-08 06:15:39 2016-02-08 12:15:39
# 3              A-4         2 2016-02-08 06:51:45 2016-02-08 12:51:45
# 4              A-5         3 2016-02-08 07:53:43 2016-02-08 13:53:43
# ...            ...       ...                 ...                 ...
# 2845337  A-2845338         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 2845338  A-2845339         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 2845339  A-2845340         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 2845340  A-2845341         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 2845341  A-2845342         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Year        Duration  Start_Hour  End_Hour  Distance(km) Side  \
# ...

# %%
plt.figure(figsize=(16, 16))
sns.set(style="whitegrid")
sns.heatmap(new_df.corr(),annot=True,cmap="coolwarm")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10892\1910559677.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(new_df.corr(),annot=True,cmap="coolwarm")
